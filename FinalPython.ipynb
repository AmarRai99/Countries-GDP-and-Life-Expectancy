# %%
import pandas as pd
from sqlalchemy import create_engine
from config import username
from config import password
# !pip install psy

# %%
Countries_GDP_Data = pd.read_csv("./Resources/countries of the world.csv")
Life_Expectancy_Data = pd.read_csv("./Resources/Life_Expectancy.csv")

# %%
Countries_GDP_Data
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
Life_Expectancy_Data
# Out:
#                                 country        alc     years
# 0                           Afghanistan   0.000000  61.25205
# 1                               Albania   4.879627  74.13000
# 2                               Algeria   0.692020  71.82955
# 3                               Andorra  12.332149  82.65301
# 4                                Angola   5.660368  51.74093
# ..                                  ...        ...       ...
# 188  Venezuela (Bolivarian Republic of)   7.736428  75.92431
# 189                            Viet Nam   2.022827  75.68709
# 190                               Yemen   0.106465  64.25762
# 191                              Zambia   0.975926  58.46280
# 192                            Zimbabwe   1.525993  58.72677
#
# [193 rows x 3 columns]

# %%
Countries_GDP_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
Life_Expectancy_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  193 non-null    object
#  1   alc      193 non-null    float64
#  2   years    193 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.6+ KB

# %%
Countries_GDP_Data.drop({"Region", "Area (sq. mi.)", "Pop. Density (per sq. mi.)", "Coastline (coast/area ratio)", "Net migration", "Infant mortality (per 1000 births)", "Literacy (%)", "Phones (per 1000)", "Arable (%)", "Crops (%)", "Other (%)", "Climate", "Birthrate", "Agriculture", "Industry", "Service"},inplace=True, axis=1)

# %%
Countries_GDP_Data.drop([47,181,221,223], inplace=True, axis=0)

# %%
Life_Expectancy_Data.drop(["alc"], inplace=True, axis=1)

# %%
Countries_GDP_Data = Countries_GDP_Data.rename(columns={"Country":"country", "Population":"population", "GDP ($ per capita)":"gdp", "Deathrate":"deathrate",})

# %%
Countries_GDP_Data["deathrate"] = Countries_GDP_Data["deathrate"].str.replace(",", ".")

# %%
new_countries_data = Countries_GDP_Data

# %%
new_countries_data["country"] = new_countries_data["country"].str.strip()

# %%
new_countries_data["country"].loc[0]
# Out:
# 'Afghanistan'

# %%
new_life_expectancy_data["country"].loc[0]
# Out:
# 'Afghanistan'

# %%
dd= pd.merge(new_countries_data, new_life_expectancy_data, on="country")
dd
# Out:
#          country  population      gdp deathrate     years
# 0    Afghanistan    31056997    700.0     20.34  61.25205
# 1        Albania     3581655   4500.0      5.22  74.13000
# 2        Algeria    32930091   6000.0      4.61  71.82955
# 3        Andorra       71201  19000.0      6.25  82.65301
# 4         Angola    12127071   1900.0      24.2  51.74093
# ..           ...         ...      ...       ...       ...
# 153   Uzbekistan    27307134   1700.0      7.84  69.20962
# 154      Vanuatu      208869   2900.0      7.82  72.28570
# 155        Yemen    21456188    800.0       8.3  64.25762
# 156       Zambia    11502010    800.0     19.93  58.46280
# 157     Zimbabwe    12236805   1900.0     21.84  58.72677
#
# [158 rows x 5 columns]

# %%
new_life_expectancy_data = Life_Expectancy_Data

# %%
new_life_expectancy_data
# Out:
#                                 country     years
# 0                           Afghanistan  61.25205
# 1                               Albania  74.13000
# 2                               Algeria  71.82955
# 3                               Andorra  82.65301
# 4                                Angola  51.74093
# ..                                  ...       ...
# 188  Venezuela (Bolivarian Republic of)  75.92431
# 189                            Viet Nam  75.68709
# 190                               Yemen  64.25762
# 191                              Zambia  58.46280
# 192                            Zimbabwe  58.72677
#
# [193 rows x 2 columns]

# %% [markdown]
# # Create A DataBase Connection to PostgreSQL

# %%
protocol="postgresql"
user = username
password_1= password
host="localhost"
port=5432
database_name="Life_Expectancy_GDP"
connection_string=f"{protocol}://{username}:{password}@{host}:{port}/{database_name}"

# %%
engine=create_engine(connection_string)
engine.table_names()
# Out:
# /var/folders/pd/tm2yj2hx5rb87k62xyb5tj6w0000gn/T/ipykernel_53563/3440626619.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['countries_gdp', 'life_expectancy']

# %%
len(new_countries_data)
# Out:
# 223

# %%
len(new_countries_data.drop_duplicates())
# Out:
# 223

# %%
new_countries_data.to_sql(name="countries_gdp",con=engine,if_exists="append",index=False)
# Out:
# 223

# %%
new_life_expectancy_data.to_sql(name="life_expectancy",con=engine,if_exists="append",index=False)
# Out:
# 193

# %%
pd.read_sql_query("Select * from countries_GDP", con=engine)
# Out:
#       id         country  population    gdp  deathrate
# 0      1     Afghanistan    31056997    700      20.34
# 1      2         Albania     3581655   4500       5.22
# 2      3         Algeria    32930091   6000       4.61
# 3      4  American Samoa       57794   8000       3.27
# 4      5         Andorra       71201  19000       6.25
# ..   ...             ...         ...    ...        ...
# 218  219  Virgin Islands      108605  17200       6.43
# 219  220       West Bank     2460492    800       3.92
# 220  221           Yemen    21456188    800       8.30
# 221  222          Zambia    11502010    800      19.93
# 222  223        Zimbabwe    12236805   1900      21.84
#
# [223 rows x 5 columns]

# %%
pd.read_sql_query("Select * from life_expectancy", con=engine)
# Out:
#       id                             country     years
# 0      1                         Afghanistan  61.25205
# 1      2                             Albania  74.13000
# 2      3                             Algeria  71.82955
# 3      4                             Andorra  82.65301
# 4      5                              Angola  51.74093
# ..   ...                                 ...       ...
# 188  189  Venezuela (Bolivarian Republic of)  75.92431
# 189  190                            Viet Nam  75.68709
# 190  191                               Yemen  64.25762
# 191  192                              Zambia  58.46280
# 192  193                            Zimbabwe  58.72677
#
# [193 rows x 3 columns]

# %%
engine.table_names()
# Out:
# /var/folders/pd/tm2yj2hx5rb87k62xyb5tj6w0000gn/T/ipykernel_53563/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['countries_gdp', 'life_expectancy']

# %%
merged = pd.read_sql_query("Select * from merged", con=engine)

# %%
merged
# Out:
#          country  population    gdp  deathrate     years
# 0    Afghanistan    31056997    700      20.34  61.25205
# 1        Albania     3581655   4500       5.22  74.13000
# 2        Algeria    32930091   6000       4.61  71.82955
# 3        Andorra       71201  19000       6.25  82.65301
# 4         Angola    12127071   1900      24.20  51.74093
# ..           ...         ...    ...        ...       ...
# 153   Uzbekistan    27307134   1700       7.84  69.20962
# 154      Vanuatu      208869   2900       7.82  72.28570
# 155        Yemen    21456188    800       8.30  64.25762
# 156       Zambia    11502010    800      19.93  58.46280
# 157     Zimbabwe    12236805   1900      21.84  58.72677
#
# [158 rows x 5 columns]

# %%
merged = {"Country":merged["country"],
          "Population":merged["population"],
          "GDP($ Per Capita)":merged["gdp"],
          "Deathrate":merged["deathrate"],
          "Years":merged["years"] 
         }


merged = pd.DataFrame(merged)
merged
# Out:
#          Country  Population  GDP($ Per Capita)  Deathrate     Years
# 0    Afghanistan    31056997                700      20.34  61.25205
# 1        Albania     3581655               4500       5.22  74.13000
# 2        Algeria    32930091               6000       4.61  71.82955
# 3        Andorra       71201              19000       6.25  82.65301
# 4         Angola    12127071               1900      24.20  51.74093
# ..           ...         ...                ...        ...       ...
# 153   Uzbekistan    27307134               1700       7.84  69.20962
# 154      Vanuatu      208869               2900       7.82  72.28570
# 155        Yemen    21456188                800       8.30  64.25762
# 156       Zambia    11502010                800      19.93  58.46280
# 157     Zimbabwe    12236805               1900      21.84  58.72677
#
# [158 rows x 5 columns]

# %%
merged.set_index("Country", inplace = True)

# %%
Top_10_GDP_Countries = merged["GDP($ Per Capita)"].nlargest(n=10)

# %%
top_GDP_countries = {"Top 10 Countries based on GDP":Top_10_GDP_Countries}

top_GDP_countries = pd.DataFrame(top_GDP_countries)
top_GDP_countries
# Out:
#              Top 10 Countries based on GDP
# Country
# Luxembourg                           55100
# Norway                               37800
# San Marino                           34600
# Switzerland                          32700
# Denmark                              31100
# Iceland                              30900
# Austria                              30000
# Canada                               29800
# Ireland                              29600
# Belgium                              29100

# %%
Bottom_10_GDP_Countries = merged["GDP($ Per Capita)"].nsmallest(n=10)

# %%
bottom_GDP_countries = {"Bottom 10 Countries based on GDP":Bottom_10_GDP_Countries}

bottom_GDP_countries = pd.DataFrame(bottom_GDP_countries)
bottom_GDP_countries
# Out:
#               Bottom 10 Countries based on GDP
# Country
# Sierra Leone                               500
# Somalia                                    500
# Burundi                                    600
# Malawi                                     600
# Afghanistan                                700
# Comoros                                    700
# Eritrea                                    700
# Ethiopia                                   700
# Kiribati                                   800
# Madagascar                                 800

# %%
top_10_LE = merged["Years"].nlargest(n=10)

# %%
Top_LE = {"Top 10 Countries based on Life Expectancy in Years":top_10_LE}

Top_LE = pd.DataFrame(Top_LE)
Top_LE
# Out:
#              Top 10 Countries based on Life Expectancy in Years
# Country
# Japan                                                 83.73987
# Switzerland                                           83.13744
# San Marino                                            83.07310
# Singapore                                             82.87928
# Italy                                                 82.86323
# Andorra                                               82.65301
# Spain                                                 82.62270
# Australia                                             82.58784
# Israel                                                82.46140
# Iceland                                               82.43079

# %%
bottom_10_LE = merged["Years"].nsmallest(n=10)

# %%
Bottom_LE = {"Bottom 10 Countries based on Life Expectancy in Years":bottom_10_LE}

Bottom_LE = pd.DataFrame(Bottom_LE)
Bottom_LE
# Out:
#                    Bottom 10 Countries based on Life Expectancy in Years
# Country
# Sierra Leone                                                45.98883
# Lesotho                                                     50.36242
# Chad                                                        51.70940
# Angola                                                      51.74093
# Swaziland                                                   53.11098
# Mozambique                                                  54.18395
# Somalia                                                     54.42672
# Nigeria                                                     54.54945
# Equatorial Guinea                                           55.93278
# Burundi                                                     56.20937
